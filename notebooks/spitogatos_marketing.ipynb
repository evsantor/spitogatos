# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 16, 12
rcParams.update({'font.size': 16})

# %%
df = pd.read_csv("cleaned_data.csv")
df.head(10)
# Out:
#          id  ranking_score  agent_id geography_name  sq_meters   price  \
# 0  42911697           47.0   14680.0   northern sub        567  200000
# 1  43018583          134.7   15502.0   northern sub        642  550000
# 2  39670968           71.0    9807.0   northern sub        320  500000
# 3  39740833          122.0   14682.0   northern sub         95  230000
# 4  39742998          126.7   14682.0   northern sub        195  370000
# 5  39813890          133.8   14682.0   northern sub        318  560000
# 6  36078547          116.5    8906.0   northern sub        291  970000
# 7  43027442          142.0   14007.0   northern sub        350  550000
# 8  36152206          154.5    8123.0   northern sub        400  850000
# 9  43045884           27.8   11545.0   northern sub        583  220000
#
#    year_of_construction     floor     subtype  rooms  ...  neoclassic  \
# 0                  2005  42911697   apartment      4  ...         0.0
# ...

# %%
sns.boxplot(x = df['price']).set_title('Price Boxplot');

# %%
price_df = df[['price', 'subtype', 'geography_name']]
price_df.groupby(['subtype', 'geography_name']).mean()
# Out:
#                                               price
# subtype           geography_name
# apartment         beesy neighborhood   1.071509e+05
#                   gentrification area  1.992086e+05
#                   northern sub         4.782278e+05
#                   south beach          4.290951e+05
# apartment complex beesy neighborhood   3.942857e+05
#                   gentrification area  5.095000e+05
#                   northern sub         3.376923e+06
#                   south beach          1.471704e+06
# building          beesy neighborhood   5.098491e+05
#                   gentrification area  1.303030e+06
#                   northern sub         1.443551e+06
#                   south beach          1.839774e+06
# bungalow          south beach          6.650000e+04
# detached          beesy neighborhood   3.143368e+05
#                   gentrification area  8.014865e+05
#                   northern sub         1.247916e+06
# ...

# %%
price_df.groupby(['subtype', 'geography_name']).median()
# Out:
#                                          price
# subtype           geography_name
# apartment         beesy neighborhood     89000
#                   gentrification area   185000
#                   northern sub          380000
#                   south beach           330000
# apartment complex beesy neighborhood    450000
#                   gentrification area   509500
#                   northern sub         2000000
#                   south beach          1200000
# building          beesy neighborhood    435000
#                   gentrification area   750000
#                   northern sub         1050000
#                   south beach          1200000
# bungalow          south beach            66500
# detached          beesy neighborhood    240000
#                   gentrification area   625000
#                   northern sub          900000
#                   south beach           950000
# loft              south beach           369000
# ...

# %%
price_df.groupby(['subtype', 'geography_name']).std()
# Out:
#                                               price
# subtype           geography_name
# apartment         beesy neighborhood   6.740050e+04
#                   gentrification area  9.441066e+04
#                   northern sub         3.737564e+05
#                   south beach          3.120114e+05
# apartment complex beesy neighborhood   1.927958e+05
#                   gentrification area  3.401184e+05
#                   northern sub         2.901122e+06
#                   south beach          1.086464e+06
# building          beesy neighborhood   3.714878e+05
#                   gentrification area  1.518651e+06
#                   northern sub         1.550713e+06
#                   south beach          1.658637e+06
# bungalow          south beach          2.121320e+03
# detached          beesy neighborhood   2.484046e+05
#                   gentrification area  4.955424e+05
#                   northern sub         1.117519e+06
# ...
